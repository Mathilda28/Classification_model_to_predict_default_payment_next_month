# %%
# Import Library
import pandas as pd

import pickle
import warnings
import numpy as np
warnings.filterwarnings(action='ignore')

# %%
# Load Model
model = pickle.load(open('/content/sample_data/income_pred.pkl', 'rb'))
model
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='most_frequent')),
#                                  ('ordinal_enc',
#                                   OrdinalEncoder(categories=[[-2, -1, 0, 1, 2,
#                                                               3, 4, 5, 6, 7,
#                                                               8],
#                                                              [-2, -1, 0, 1, 2,
#                                                               3, 4, 5, 6, 7],
#                                                              [-2, -1, 0, 1, 2,
#                                                               3, 4, 5, 6, 7],
#                                                              [-2, -1, 0, 1, 2,
#                                                               3, 4, 5, 6, 7,
#                                                               8],
# ...

# %%
# semua fitur/kolom
features = [
    'pay_0',
    'pay_2',
    'pay_3',
    'pay_4',
    'pay_5',
    'pay_6',
    ]

# artificial data infer
pay_0 = np.random.randint(0,8,size=10)
pay_2 = np.random.randint(0,7,size=10)
pay_3 = np.random.randint(0,7,size=10)
pay_4 = np.random.randint(0,7,size=10)
pay_5 = np.random.randint(0,7,size=10)
pay_6 = np.random.randint(0,7,size=10)


D = {
    'pay_0':pay_0,
    'pay_2':pay_2,
    'pay_3':pay_3,
    'pay_4':pay_4,
    'pay_5':pay_5,
    'pay_6':pay_6,
    }
df = pd.DataFrame(data=D,columns=features)

# %%
df.head().T
# Out:
#        0  1  2  3  4
# pay_0  4  7  5  2  3
# pay_2  6  5  2  6  2
# pay_3  5  3  1  0  2
# pay_4  7  3  1  7  3
# pay_5  3  3  8  4  2
# pay_6  1  4  1  7  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pay_0   10 non-null     int64
#  1   pay_2   10 non-null     int64
#  2   pay_3   10 non-null     int64
#  3   pay_4   10 non-null     int64
#  4   pay_5   10 non-null     int64
#  5   pay_6   10 non-null     int64
# dtypes: int64(6)
# memory usage: 608.0 bytes

# %% [markdown]
# # XI. Model Inference

# %%
# predict default payment
pred_default_payment = model.predict(df)

# %%
#inference result
df['pred_default_payment'] = pred_default_payment
df
# Out:
#    pay_0  pay_2  pay_3  pay_4  pay_5  pay_6  pred_default_payment
# 0      0      0      2      6      0      1                     1
# 1      4      5      2      4      4      2                     1
# 2      3      0      1      6      0      5                     1
# 3      2      5      3      5      0      6                     1
# 4      0      5      3      1      4      5                     1
# 5      6      6      4      1      3      5                     1
# 6      3      4      2      6      1      3                     1
# 7      6      5      6      1      0      5                     1
# 8      5      0      5      5      3      1                     1
# 9      2      0      0      1      6      3                     1

# %% [markdown]
# # XI. Pengambilan Kesimpulan

# %% [markdown]
# - Scoring recall digunakan untuk melihat false positif agar kita mengetahui total nasabah yang belum bayar tapi terbaca sudah bayar agar kita bisa meminimalisir kerugian dari perusahaan dengan jenis layanan kartu kredit.
# - Saya juga telah membuat model naive bayes dengan hyperparameter tuning, tetapi model tersebut memiliki kenaikan hanya mencapai 0.44. Hal ini dapat disebabkan oleh beberapa hal yaitu diantaranya kelas target yang tidak seimbang.
# - Model yang digunkanan untuk memprediksi kemungkinan tersebut adalah model Naive Bayes dengan nilai recall 0.44 yaitu nilai sama
# -  Berdasarkan hasil olah data diatas, model Gaussian Naive Bayes (NB) menunjukkan performa yang lebih baik dalam hal recall dibandingkan dengan model-model lain yang dievaluasi. Oleh karena itu, model NB dapat dianggap sebagai salah satu pilihan yang lebih baik untuk tugas klasifikasi ini. Namun, penting untuk melakukan evaluasi lebih lanjut dan mempertimbangkan faktor lain seperti metrik evaluasi lainnya, konteks masalah, dan pertimbangan lain yang relevan sebelum membuat keputusan akhir.
